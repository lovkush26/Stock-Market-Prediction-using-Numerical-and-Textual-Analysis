# %% [markdown]
# # GRIP @ The Sparks Foundation

# %% [markdown]
# ## Data Science and Business Analytics

# %% [markdown]
# ### Stock Market Prediction using Numerical and Textual Analysis - By Lovkush Sharma

# %% [markdown]
# <hr>

# %% [markdown]
# ## Importing the libraries

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from keras.layers import Dense, LSTM
from keras.models import Sequential
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from textblob import TextBlob
from datetime import datetime
from sklearn import metrics 
import pandas as pd 
import numpy as np
import math
import re

# %% [markdown]
# ## Loading and Testing Stock Market Dataset

# %%
df_prices = pd.read_csv('c:\\Users\\Lovkush\\Downloads\\StockMarketPrediction-master\\StockMarketPrediction-master\\Datasets\\stockprices.csv')
df_prices.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  2017-03-01  26.010000  26.379999  25.860001  25.900000  24.324486   55900
# 1  2017-03-02  25.830000  25.920000  25.660000  25.770000  24.202393   41800
# 2  2017-03-03  25.780001  26.070000  25.459999  25.780001  24.211786   70400
# 3  2017-03-06  25.680000  25.889999  25.440001  25.830000  24.258745   42600
# 4  2017-03-07  25.700001  25.879999  25.549999  25.840000  24.268139   45600

# %% [markdown]
# ## Loading and Testing News Dataset

# %%
cols = ['Date', 'Category', 'News']
df_news = pd.read_csv(r"c:\Users\Lovkush\Downloads\StockMarketPrediction-master\StockMarketPrediction-master\Datasets\news.csv", names=cols)
df_news = df_news.dropna(axis=0, how='any')
df_news
# Out:
#             Date                               Category  \
# 0       20170101                      life-style.beauty
# 1       20170101  life-style.health-fitness.weight-loss
# 2       20170101    life-style.health-fitness.de-stress
# 3       20170101    life-style.health-fitness.de-stress
# 4       20170101                 life-style.home-garden
# ...          ...                                    ...
# 873610  20201231                           city.jodhpur
# 873611  20201231                           city.udaipur
# 873612  20201231                             city.ajmer
# 873613  20201231                                removed
# 873614  20201231      entertainment.bengali.movies.news
#
#                                                      News
# 0                                          Look-ing ahead
# 1                                         Genie in a diet
# 2                                       17 ideas for 2017
# 3       I started living my life to my highest potenti...
# 4                                      Hygge up your home
# ...                                                   ...
# 873610  Covid-19: Despite dip in cases; Rajasthan amon...
# 873611  Covid-19: Despite dip in cases; Rajasthan amon...
# 873612  Covid-19: Despite dip in cases; Rajasthan amon...
# 873613  Govt extends deadline for use of FASTag till F...
# 873614  Celebs plan to party safely and responsibly on...
#
# [873615 rows x 3 columns]

# %% [markdown]
# ## Cleaning Data - Dropping Unwanted Values

# %%
df_news = df_news.drop_duplicates('Date', keep='first').sort_index()
df_news = df_news.reset_index()
df_news
# Out:
#        index      Date                             Category  \
# 0          0  20170101                    life-style.beauty
# 1         84  20170102  life-style.health-fitness.de-stress
# 2        784  20170103                        city.bareilly
# 3       1483  20170104                        tv.news.hindi
# 4       2183  20170105               life-style.home-garden
# ...      ...       ...                                  ...
# 1456  871121  20201227    entertainment.bengali.movies.news
# 1457  871620  20201228                  astrology.horoscope
# 1458  872118  20201229                        city.bareilly
# 1459  872617  20201230           astrology.numerology-tarot
# 1460  873117  20201231                  astrology.horoscope
#
#                                                    News
# 0                                        Look-ing ahead
# 1            Destress plan for the first Monday of 2017
# 2     State opposition dismisses Samajwadi Party feu...
# 3     Rudra Soni ready to go bald for TV; not Bollyw...
# 4                        Decoding Buddhist prayer flags
# ...                                                 ...
# 1456  #BigInterview! Dhritiman Chatterjee: Nobody da...
# 1457  Horoscope Today; 28 December 2020: Check astro...
# 1458  Man recovers charred remains of 'thief' from h...
# 1459  Numerology Readings 30 December 2020: Predicti...
# 1460  Horoscope Today; 31 December 2020: Check astro...
#
# [1461 rows x 4 columns]

# %% [markdown]
# ## Storing City Data

# %%
city_data = df_news[df_news['Category'].str.contains('^city\.[a-z]+$', regex=True)]
city_data
# Out:
#        index      Date        Category  \
# 2        784  20170103   city.bareilly
# 5       2883  20170106   city.bareilly
# 6       3582  20170107     city.mysuru
# 9       5682  20170110    city.lucknow
# 12      7782  20170113      city.kochi
# ...      ...       ...             ...
# 1444  865132  20201215     city.nagpur
# 1447  866631  20201218  city.ahmedabad
# 1448  867130  20201219     city.mumbai
# 1452  869128  20201223   city.vadodara
# 1458  872118  20201229   city.bareilly
#
#                                                    News
# 2     State opposition dismisses Samajwadi Party feu...
# 5     Will stay bachelor to serve Akhilesh; says thr...
# 6     Helpdesk to aid bizmen get Udyog Aadhaar Memor...
# 9          Mulayam Singh calls off January 5 convention
# 12       Vidya Balan opts out of biopic on Madhavikutty
# ...                                                 ...
# 1444  1;147 RT-PCR tests in a day; only 3 found +ve ...
# 1447  Cops; panch witnesses sniffed suspects' mouths...
# 1448  Rally champion only crowned if half WRC season...
# 1452        Sawmill in Makarpura GIDC gutted; none hurt
# 1458  Man recovers charred remains of 'thief' from h...
#
# [626 rows x 4 columns]

# %% [markdown]
# ## Extracting City Data

# %%
city_split = pd.DataFrame(columns=['City_Name'])
city_split['City_Name'] = city_data.Category.str.split('.',expand=True)[1]
city_data = pd.concat([city_data,city_split],axis=1)
city_data.drop(columns=['Category'],axis=1, inplace=True)
city_data.reset_index(inplace=True)
city_data.drop(['level_0','index'],axis=1, inplace=True)
city_data
# Out:
#          Date                                               News  City_Name
# 0    20170103  State opposition dismisses Samajwadi Party feu...   bareilly
# 1    20170106  Will stay bachelor to serve Akhilesh; says thr...   bareilly
# 2    20170107  Helpdesk to aid bizmen get Udyog Aadhaar Memor...     mysuru
# 3    20170110       Mulayam Singh calls off January 5 convention    lucknow
# 4    20170113     Vidya Balan opts out of biopic on Madhavikutty      kochi
# ..        ...                                                ...        ...
# 621  20201215  1;147 RT-PCR tests in a day; only 3 found +ve ...     nagpur
# 622  20201218  Cops; panch witnesses sniffed suspects' mouths...  ahmedabad
# 623  20201219  Rally champion only crowned if half WRC season...     mumbai
# 624  20201223        Sawmill in Makarpura GIDC gutted; none hurt   vadodara
# 625  20201229  Man recovers charred remains of 'thief' from h...   bareilly
#
# [626 rows x 3 columns]

# %% [markdown]
# ## Preprocessing - Converting the 'Date' columns to Datetime

# %%
df_news['Date'] = pd.to_datetime(df_news['Date'], format='%Y%m%d')
df_prices['Date'] = pd.to_datetime(df_prices.Date, format='%Y-%m-%d')
df_prices
# Out:
#            Date       Open       High        Low      Close  Adj Close  Volume
# 0    2017-03-01  26.010000  26.379999  25.860001  25.900000  24.324486   55900
# 1    2017-03-02  25.830000  25.920000  25.660000  25.770000  24.202393   41800
# 2    2017-03-03  25.780001  26.070000  25.459999  25.780001  24.211786   70400
# 3    2017-03-06  25.680000  25.889999  25.440001  25.830000  24.258745   42600
# 4    2017-03-07  25.700001  25.879999  25.549999  25.840000  24.268139   45600
# ...         ...        ...        ...        ...        ...        ...     ...
# 1253 2022-02-18  49.080002  49.950001  48.669998  49.500000  49.500000  130500
# 1254 2022-02-22  49.080002  50.540001  48.970001  49.490002  49.490002  107200
# 1255 2022-02-23  50.099998  50.320000  49.049999  49.480000  49.480000  125300
# 1256 2022-02-24  48.349998  49.709999  47.070000  48.980000  48.980000  189600
# 1257 2022-02-25  49.310001  50.369999  47.529999  50.340000  50.340000  136900
#
# [1258 rows x 7 columns]

# %% [markdown]
# ## Plotting the Data

# %%
plt.figure(figsize=(16,8))
plt.title('Close Price history\n')
plt.xlabel('Time (Year)')
plt.ylabel('Close Price')
plt.plot(df_prices['Close'])

# %% [markdown]
# ## Storing Closing Stock

# %%
def new_dataset(df_prices2, look_back=1):
    dataX, dataY = [], []
    for i in range(len(df_prices2)-look_back):
        a = df_prices2[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(df_prices2[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

df2 = pd.read_csv('Datasets/stockprices.csv', usecols=[5], engine='python')
df2.dropna(inplace=True)
df2 = df2.values
df2 = df2.astype('float32')

# %% [markdown]
# ## Data Normalization

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
df2 = scaler.fit_transform(df2)

train_size = int(len(df2) * 0.80)
test_size = len(df2) - train_size
train, test = df2[0:train_size,:], df2[train_size:len(df2),:]

look_back = 2
trainX, trainY = new_dataset(train, look_back)
testX, testY = new_dataset(test, look_back)

trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %% [markdown]
# ## LSTM Neural Network Model for Numerical Analysis

# %%
model = Sequential()
model.add(LSTM(7, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=500, batch_size=10, verbose=2)
# Out:
# c:\Users\Lovkush\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/500
# 101/101 - 3s - 33ms/step - loss: 0.0091
# Epoch 2/500
# 101/101 - 0s - 3ms/step - loss: 0.0031
# Epoch 3/500
# 101/101 - 0s - 4ms/step - loss: 0.0020
# Epoch 4/500
# 101/101 - 0s - 3ms/step - loss: 9.9548e-04
# Epoch 5/500
# 101/101 - 0s - 3ms/step - loss: 3.8920e-04
# Epoch 6/500
# 101/101 - 0s - 4ms/step - loss: 1.7386e-04
# Epoch 7/500
# 101/101 - 0s - 4ms/step - loss: 1.3287e-04
# Epoch 8/500
# 101/101 - 0s - 4ms/step - loss: 1.2866e-04
# Epoch 9/500
# 101/101 - 0s - 4ms/step - loss: 1.2782e-04
# Epoch 10/500
# 101/101 - 0s - 3ms/step - loss: 1.2814e-04
# Epoch 11/500
# 101/101 - 0s - 3ms/step - loss: 1.2734e-04
# Epoch 12/500
# 101/101 - 0s - 3ms/step - loss: 1.2543e-04
# Epoch 13/500
# 101/101 - 0s - 2ms/step - loss: 1.2808e-04
# Epoch 14/500
# 101/101 - 0s - 2ms/step - loss: 1.2667e-04
# Epoch 15/500
# 101/101 - 0s - 2ms/step - loss: 1.2431e-04
# Epoch 16/500
# 101/101 - 0s - 2ms/step - loss: 1.2381e-04
# Epoch 17/500
# 101/101 - 0s - 2ms/step - loss: 1.2356e-04
# Epoch 18/500
# 101/101 - 0s - 2ms/step - loss: 1.2621e-04
# Epoch 19/500
# 101/101 - 0s - 2ms/step - loss: 1.2383e-04
# Epoch 20/500
# 101/101 - 0s - 3ms/step - loss: 1.2192e-04
# Epoch 21/500
# 101/101 - 0s - 4ms/step - loss: 1.2578e-04
# Epoch 22/500
# 101/101 - 0s - 3ms/step - loss: 1.2150e-04
# Epoch 23/500
# 101/101 - 0s - 3ms/step - loss: 1.2270e-04
# Epoch 24/500
# 101/101 - 0s - 3ms/step - loss: 1.2125e-04
# Epoch 25/500
# 101/101 - 0s - 4ms/step - loss: 1.2190e-04
# Epoch 26/500
# 101/101 - 0s - 3ms/step - loss: 1.2437e-04
# Epoch 27/500
# 101/101 - 0s - 2ms/step - loss: 1.1929e-04
# Epoch 28/500
# 101/101 - 0s - 2ms/step - loss: 1.1927e-04
# Epoch 29/500
# 101/101 - 0s - 2ms/step - loss: 1.1845e-04
# Epoch 30/500
# 101/101 - 0s - 2ms/step - loss: 1.1947e-04
# Epoch 31/500
# 101/101 - 0s - 2ms/step - loss: 1.1612e-04
# Epoch 32/500
# 101/101 - 0s - 3ms/step - loss: 1.1814e-04
# Epoch 33/500
# 101/101 - 0s - 2ms/step - loss: 1.1766e-04
# Epoch 34/500
# 101/101 - 0s - 3ms/step - loss: 1.1715e-04
# Epoch 35/500
# 101/101 - 0s - 2ms/step - loss: 1.1805e-04
# Epoch 36/500
# 101/101 - 0s - 3ms/step - loss: 1.1873e-04
# Epoch 37/500
# 101/101 - 0s - 2ms/step - loss: 1.1595e-04
# Epoch 38/500
# 101/101 - 0s - 2ms/step - loss: 1.1653e-04
# Epoch 39/500
# 101/101 - 0s - 3ms/step - loss: 1.1853e-04
# Epoch 40/500
# 101/101 - 0s - 3ms/step - loss: 1.1716e-04
# Epoch 41/500
# 101/101 - 0s - 3ms/step - loss: 1.1883e-04
# Epoch 42/500
# 101/101 - 0s - 4ms/step - loss: 1.1803e-04
# Epoch 43/500
# 101/101 - 0s - 4ms/step - loss: 1.1475e-04
# Epoch 44/500
# 101/101 - 0s - 4ms/step - loss: 1.1885e-04
# Epoch 45/500
# 101/101 - 0s - 4ms/step - loss: 1.1610e-04
# Epoch 46/500
# 101/101 - 0s - 4ms/step - loss: 1.1154e-04
# Epoch 47/500
# 101/101 - 0s - 4ms/step - loss: 1.1470e-04
# Epoch 48/500
# 101/101 - 0s - 4ms/step - loss: 1.1434e-04
# Epoch 49/500
# 101/101 - 0s - 4ms/step - loss: 1.2298e-04
# Epoch 50/500
# 101/101 - 0s - 4ms/step - loss: 1.1659e-04
# Epoch 51/500
# 101/101 - 0s - 4ms/step - loss: 1.1853e-04
# Epoch 52/500
# 101/101 - 0s - 4ms/step - loss: 1.1403e-04
# Epoch 53/500
# 101/101 - 0s - 4ms/step - loss: 1.1883e-04
# Epoch 54/500
# 101/101 - 0s - 4ms/step - loss: 1.1439e-04
# Epoch 55/500
# 101/101 - 0s - 4ms/step - loss: 1.1273e-04
# Epoch 56/500
# 101/101 - 0s - 4ms/step - loss: 1.1186e-04
# Epoch 57/500
# 101/101 - 0s - 4ms/step - loss: 1.1160e-04
# Epoch 58/500
# 101/101 - 0s - 4ms/step - loss: 1.1332e-04
# Epoch 59/500
# 101/101 - 0s - 4ms/step - loss: 1.1318e-04
# Epoch 60/500
# 101/101 - 0s - 4ms/step - loss: 1.1176e-04
# Epoch 61/500
# 101/101 - 0s - 4ms/step - loss: 1.1017e-04
# Epoch 62/500
# 101/101 - 0s - 4ms/step - loss: 1.1156e-04
# Epoch 63/500
# 101/101 - 0s - 4ms/step - loss: 1.1204e-04
# Epoch 64/500
# 101/101 - 0s - 4ms/step - loss: 1.1015e-04
# Epoch 65/500
# 101/101 - 0s - 5ms/step - loss: 1.1568e-04
# Epoch 66/500
# 101/101 - 0s - 5ms/step - loss: 1.1257e-04
# Epoch 67/500
# 101/101 - 0s - 4ms/step - loss: 1.1413e-04
# Epoch 68/500
# 101/101 - 0s - 4ms/step - loss: 1.1225e-04
# Epoch 69/500
# 101/101 - 0s - 4ms/step - loss: 1.0917e-04
# Epoch 70/500
# 101/101 - 0s - 4ms/step - loss: 1.1342e-04
# Epoch 71/500
# 101/101 - 0s - 4ms/step - loss: 1.1154e-04
# Epoch 72/500
# 101/101 - 0s - 4ms/step - loss: 1.1015e-04
# Epoch 73/500
# 101/101 - 0s - 4ms/step - loss: 1.1838e-04
# Epoch 74/500
# 101/101 - 0s - 5ms/step - loss: 1.1266e-04
# Epoch 75/500
# 101/101 - 1s - 5ms/step - loss: 1.1380e-04
# Epoch 76/500
# 101/101 - 1s - 5ms/step - loss: 1.1556e-04
# Epoch 77/500
# 101/101 - 0s - 4ms/step - loss: 1.1466e-04
# Epoch 78/500
# 101/101 - 1s - 5ms/step - loss: 1.0995e-04
# Epoch 79/500
# 101/101 - 1s - 5ms/step - loss: 1.0854e-04
# Epoch 80/500
# 101/101 - 1s - 5ms/step - loss: 1.0950e-04
# Epoch 81/500
# 101/101 - 1s - 5ms/step - loss: 1.0968e-04
# Epoch 82/500
# 101/101 - 1s - 5ms/step - loss: 1.0960e-04
# Epoch 83/500
# 101/101 - 0s - 5ms/step - loss: 1.0889e-04
# Epoch 84/500
# 101/101 - 0s - 5ms/step - loss: 1.0917e-04
# Epoch 85/500
# 101/101 - 0s - 5ms/step - loss: 1.1043e-04
# Epoch 86/500
# 101/101 - 0s - 4ms/step - loss: 1.1656e-04
# Epoch 87/500
# 101/101 - 0s - 5ms/step - loss: 1.0817e-04
# Epoch 88/500
# 101/101 - 0s - 5ms/step - loss: 1.0624e-04
# Epoch 89/500
# 101/101 - 0s - 4ms/step - loss: 1.1028e-04
# Epoch 90/500
# 101/101 - 0s - 4ms/step - loss: 1.0860e-04
# Epoch 91/500
# 101/101 - 0s - 5ms/step - loss: 1.0881e-04
# Epoch 92/500
# 101/101 - 0s - 5ms/step - loss: 1.0893e-04
# Epoch 93/500
# 101/101 - 0s - 5ms/step - loss: 1.0718e-04
# Epoch 94/500
# 101/101 - 0s - 4ms/step - loss: 1.1052e-04
# Epoch 95/500
# 101/101 - 0s - 4ms/step - loss: 1.0736e-04
# Epoch 96/500
# 101/101 - 0s - 5ms/step - loss: 1.0956e-04
# Epoch 97/500
# 101/101 - 0s - 5ms/step - loss: 1.0550e-04
# Epoch 98/500
# 101/101 - 0s - 5ms/step - loss: 1.0441e-04
# Epoch 99/500
# 101/101 - 0s - 5ms/step - loss: 1.1137e-04
# Epoch 100/500
# 101/101 - 0s - 5ms/step - loss: 1.0630e-04
# Epoch 101/500
# 101/101 - 0s - 5ms/step - loss: 1.0718e-04
# Epoch 102/500
# 101/101 - 0s - 4ms/step - loss: 1.0809e-04
# Epoch 103/500
# 101/101 - 0s - 4ms/step - loss: 1.0637e-04
# Epoch 104/500
# 101/101 - 0s - 4ms/step - loss: 1.0289e-04
# Epoch 105/500
# 101/101 - 0s - 4ms/step - loss: 1.0323e-04
# Epoch 106/500
# 101/101 - 0s - 4ms/step - loss: 1.0816e-04
# Epoch 107/500
# 101/101 - 0s - 5ms/step - loss: 1.0554e-04
# Epoch 108/500
# 101/101 - 0s - 5ms/step - loss: 1.0600e-04
# Epoch 109/500
# 101/101 - 1s - 6ms/step - loss: 1.0779e-04
# Epoch 110/500
# 101/101 - 1s - 6ms/step - loss: 1.1055e-04
# Epoch 111/500
# 101/101 - 0s - 5ms/step - loss: 1.0896e-04
# Epoch 112/500
# 101/101 - 0s - 5ms/step - loss: 1.0721e-04
# Epoch 113/500
# 101/101 - 1s - 5ms/step - loss: 1.0600e-04
# Epoch 114/500
# 101/101 - 0s - 5ms/step - loss: 1.0907e-04
# Epoch 115/500
# 101/101 - 0s - 5ms/step - loss: 1.0355e-04
# Epoch 116/500
# 101/101 - 0s - 5ms/step - loss: 1.0542e-04
# Epoch 117/500
# 101/101 - 0s - 5ms/step - loss: 1.0283e-04
# Epoch 118/500
# 101/101 - 0s - 5ms/step - loss: 1.1396e-04
# Epoch 119/500
# 101/101 - 0s - 5ms/step - loss: 1.0037e-04
# Epoch 120/500
# 101/101 - 0s - 4ms/step - loss: 1.0323e-04
# Epoch 121/500
# 101/101 - 0s - 4ms/step - loss: 1.0124e-04
# Epoch 122/500
# 101/101 - 0s - 5ms/step - loss: 1.1037e-04
# Epoch 123/500
# 101/101 - 1s - 5ms/step - loss: 1.0241e-04
# Epoch 124/500
# 101/101 - 0s - 5ms/step - loss: 1.0724e-04
# Epoch 125/500
# 101/101 - 0s - 5ms/step - loss: 1.0258e-04
# Epoch 126/500
# 101/101 - 0s - 5ms/step - loss: 1.0097e-04
# Epoch 127/500
# 101/101 - 0s - 4ms/step - loss: 1.0322e-04
# Epoch 128/500
# 101/101 - 0s - 4ms/step - loss: 9.9605e-05
# Epoch 129/500
# 101/101 - 0s - 4ms/step - loss: 1.0048e-04
# Epoch 130/500
# 101/101 - 0s - 5ms/step - loss: 1.0286e-04
# Epoch 131/500
# 101/101 - 0s - 4ms/step - loss: 1.0326e-04
# Epoch 132/500
# 101/101 - 0s - 4ms/step - loss: 1.0320e-04
# Epoch 133/500
# 101/101 - 0s - 5ms/step - loss: 1.0018e-04
# Epoch 134/500
# 101/101 - 0s - 4ms/step - loss: 1.0390e-04
# Epoch 135/500
# 101/101 - 0s - 5ms/step - loss: 1.0113e-04
# Epoch 136/500
# 101/101 - 0s - 5ms/step - loss: 9.8913e-05
# Epoch 137/500
# 101/101 - 0s - 4ms/step - loss: 1.0252e-04
# Epoch 138/500
# 101/101 - 0s - 5ms/step - loss: 9.7999e-05
# Epoch 139/500
# 101/101 - 0s - 5ms/step - loss: 9.9537e-05
# Epoch 140/500
# 101/101 - 1s - 6ms/step - loss: 9.8031e-05
# Epoch 141/500
# 101/101 - 1s - 5ms/step - loss: 1.0358e-04
# Epoch 142/500
# 101/101 - 0s - 5ms/step - loss: 1.0040e-04
# Epoch 143/500
# 101/101 - 0s - 5ms/step - loss: 9.8882e-05
# Epoch 144/500
# 101/101 - 1s - 5ms/step - loss: 9.7053e-05
# Epoch 145/500
# 101/101 - 1s - 5ms/step - loss: 9.4549e-05
# Epoch 146/500
# 101/101 - 1s - 5ms/step - loss: 9.8519e-05
# Epoch 147/500
# 101/101 - 0s - 5ms/step - loss: 9.8604e-05
# Epoch 148/500
# 101/101 - 0s - 5ms/step - loss: 9.7641e-05
# Epoch 149/500
# 101/101 - 0s - 5ms/step - loss: 9.7391e-05
# Epoch 150/500
# 101/101 - 0s - 5ms/step - loss: 9.8285e-05
# Epoch 151/500
# 101/101 - 0s - 5ms/step - loss: 9.8005e-05
# Epoch 152/500
# 101/101 - 0s - 5ms/step - loss: 9.6190e-05
# Epoch 153/500
# 101/101 - 0s - 5ms/step - loss: 9.7017e-05
# Epoch 154/500
# 101/101 - 0s - 4ms/step - loss: 9.7592e-05
# Epoch 155/500
# 101/101 - 0s - 5ms/step - loss: 9.6304e-05
# Epoch 156/500
# 101/101 - 0s - 5ms/step - loss: 9.4223e-05
# Epoch 157/500
# 101/101 - 0s - 5ms/step - loss: 9.6312e-05
# Epoch 158/500
# 101/101 - 0s - 5ms/step - loss: 1.0008e-04
# Epoch 159/500
# 101/101 - 1s - 5ms/step - loss: 9.5716e-05
# Epoch 160/500
# 101/101 - 0s - 5ms/step - loss: 9.4646e-05
# Epoch 161/500
# 101/101 - 1s - 5ms/step - loss: 9.5492e-05
# Epoch 162/500
# 101/101 - 0s - 4ms/step - loss: 9.9110e-05
# Epoch 163/500
# 101/101 - 0s - 5ms/step - loss: 9.6104e-05
# Epoch 164/500
# 101/101 - 0s - 5ms/step - loss: 9.5155e-05
# Epoch 165/500
# 101/101 - 0s - 5ms/step - loss: 9.3930e-05
# Epoch 166/500
# 101/101 - 1s - 5ms/step - loss: 9.7466e-05
# Epoch 167/500
# 101/101 - 1s - 5ms/step - loss: 9.2298e-05
# Epoch 168/500
# 101/101 - 0s - 5ms/step - loss: 9.3254e-05
# Epoch 169/500
# 101/101 - 0s - 5ms/step - loss: 9.3726e-05
# Epoch 170/500
# 101/101 - 0s - 5ms/step - loss: 9.4355e-05
# Epoch 171/500
# 101/101 - 0s - 5ms/step - loss: 9.4628e-05
# Epoch 172/500
# 101/101 - 0s - 4ms/step - loss: 9.7201e-05
# Epoch 173/500
# 101/101 - 0s - 5ms/step - loss: 9.3030e-05
# Epoch 174/500
# 101/101 - 1s - 5ms/step - loss: 9.2796e-05
# Epoch 175/500
# 101/101 - 1s - 5ms/step - loss: 9.7106e-05
# Epoch 176/500
# 101/101 - 0s - 5ms/step - loss: 9.2950e-05
# Epoch 177/500
# 101/101 - 0s - 5ms/step - loss: 9.3944e-05
# Epoch 178/500
# 101/101 - 0s - 5ms/step - loss: 9.2408e-05
# Epoch 179/500
# 101/101 - 1s - 5ms/step - loss: 9.4005e-05
# Epoch 180/500
# 101/101 - 0s - 5ms/step - loss: 9.2581e-05
# Epoch 181/500
# 101/101 - 1s - 5ms/step - loss: 9.3429e-05
# Epoch 182/500
# 101/101 - 1s - 5ms/step - loss: 9.4446e-05
# Epoch 183/500
# 101/101 - 0s - 5ms/step - loss: 9.5259e-05
# Epoch 184/500
# 101/101 - 0s - 5ms/step - loss: 9.4723e-05
# Epoch 185/500
# 101/101 - 0s - 5ms/step - loss: 9.6097e-05
# Epoch 186/500
# 101/101 - 0s - 5ms/step - loss: 9.2619e-05
# Epoch 187/500
# 101/101 - 0s - 5ms/step - loss: 9.4256e-05
# Epoch 188/500
# 101/101 - 0s - 5ms/step - loss: 9.2219e-05
# Epoch 189/500
# 101/101 - 0s - 4ms/step - loss: 9.9667e-05
# Epoch 190/500
# 101/101 - 0s - 4ms/step - loss: 9.1711e-05
# Epoch 191/500
# 101/101 - 0s - 5ms/step - loss: 9.2163e-05
# Epoch 192/500
# 101/101 - 0s - 5ms/step - loss: 9.2737e-05
# Epoch 193/500
# 101/101 - 1s - 5ms/step - loss: 9.3595e-05
# Epoch 194/500
# 101/101 - 0s - 4ms/step - loss: 9.3647e-05
# Epoch 195/500
# 101/101 - 0s - 4ms/step - loss: 9.3831e-05
# Epoch 196/500
# 101/101 - 0s - 5ms/step - loss: 9.3132e-05
# Epoch 197/500
# 101/101 - 0s - 5ms/step - loss: 9.4958e-05
# Epoch 198/500
# 101/101 - 0s - 5ms/step - loss: 9.3678e-05
# Epoch 199/500
# 101/101 - 0s - 5ms/step - loss: 9.2923e-05
# Epoch 200/500
# 101/101 - 0s - 5ms/step - loss: 9.4057e-05
# Epoch 201/500
# 101/101 - 0s - 5ms/step - loss: 9.1469e-05
# Epoch 202/500
# 101/101 - 0s - 5ms/step - loss: 9.1254e-05
# Epoch 203/500
# 101/101 - 0s - 5ms/step - loss: 9.4334e-05
# Epoch 204/500
# 101/101 - 0s - 5ms/step - loss: 9.8908e-05
# Epoch 205/500
# 101/101 - 0s - 5ms/step - loss: 9.7203e-05
# Epoch 206/500
# 101/101 - 0s - 5ms/step - loss: 9.5928e-05
# Epoch 207/500
# 101/101 - 0s - 5ms/step - loss: 9.2636e-05
# Epoch 208/500
# 101/101 - 0s - 4ms/step - loss: 9.3756e-05
# Epoch 209/500
# 101/101 - 0s - 5ms/step - loss: 9.3738e-05
# Epoch 210/500
# 101/101 - 0s - 4ms/step - loss: 9.2964e-05
# Epoch 211/500
# 101/101 - 0s - 4ms/step - loss: 9.5386e-05
# Epoch 212/500
# 101/101 - 0s - 5ms/step - loss: 9.5422e-05
# Epoch 213/500
# 101/101 - 0s - 5ms/step - loss: 9.2901e-05
# Epoch 214/500
# 101/101 - 0s - 5ms/step - loss: 9.3220e-05
# Epoch 215/500
# 101/101 - 1s - 5ms/step - loss: 9.0949e-05
# Epoch 216/500
# 101/101 - 1s - 5ms/step - loss: 9.1431e-05
# Epoch 217/500
# 101/101 - 1s - 5ms/step - loss: 9.5342e-05
# Epoch 218/500
# 101/101 - 0s - 5ms/step - loss: 9.4967e-05
# Epoch 219/500
# 101/101 - 0s - 5ms/step - loss: 9.3879e-05
# Epoch 220/500
# 101/101 - 0s - 5ms/step - loss: 9.2169e-05
# Epoch 221/500
# 101/101 - 1s - 5ms/step - loss: 9.4925e-05
# Epoch 222/500
# 101/101 - 0s - 5ms/step - loss: 9.5247e-05
# Epoch 223/500
# 101/101 - 1s - 5ms/step - loss: 9.1725e-05
# Epoch 224/500
# 101/101 - 0s - 5ms/step - loss: 9.4209e-05
# Epoch 225/500
# 101/101 - 0s - 5ms/step - loss: 9.1891e-05
# Epoch 226/500
# 101/101 - 0s - 4ms/step - loss: 9.5743e-05
# Epoch 227/500
# 101/101 - 0s - 5ms/step - loss: 9.3646e-05
# Epoch 228/500
# 101/101 - 0s - 4ms/step - loss: 9.3021e-05
# Epoch 229/500
# 101/101 - 0s - 5ms/step - loss: 9.3185e-05
# Epoch 230/500
# 101/101 - 1s - 5ms/step - loss: 9.3331e-05
# Epoch 231/500
# 101/101 - 0s - 5ms/step - loss: 9.4344e-05
# Epoch 232/500
# 101/101 - 1s - 5ms/step - loss: 9.2949e-05
# Epoch 233/500
# 101/101 - 0s - 5ms/step - loss: 9.3973e-05
# Epoch 234/500
# 101/101 - 0s - 4ms/step - loss: 9.3435e-05
# Epoch 235/500
# 101/101 - 0s - 5ms/step - loss: 9.7800e-05
# Epoch 236/500
# 101/101 - 0s - 5ms/step - loss: 9.3135e-05
# Epoch 237/500
# 101/101 - 0s - 4ms/step - loss: 9.2814e-05
# Epoch 238/500
# 101/101 - 0s - 5ms/step - loss: 9.3398e-05
# Epoch 239/500
# 101/101 - 0s - 5ms/step - loss: 9.0679e-05
# Epoch 240/500
# 101/101 - 1s - 5ms/step - loss: 9.3499e-05
# Epoch 241/500
# 101/101 - 0s - 5ms/step - loss: 9.6171e-05
# Epoch 242/500
# 101/101 - 0s - 5ms/step - loss: 9.5246e-05
# Epoch 243/500
# 101/101 - 0s - 5ms/step - loss: 9.2896e-05
# Epoch 244/500
# 101/101 - 0s - 5ms/step - loss: 9.1288e-05
# Epoch 245/500
# 101/101 - 0s - 4ms/step - loss: 9.4216e-05
# Epoch 246/500
# 101/101 - 1s - 5ms/step - loss: 9.1220e-05
# Epoch 247/500
# 101/101 - 0s - 5ms/step - loss: 9.1955e-05
# Epoch 248/500
# 101/101 - 0s - 5ms/step - loss: 9.7674e-05
# Epoch 249/500
# 101/101 - 1s - 5ms/step - loss: 9.2957e-05
# Epoch 250/500
# 101/101 - 0s - 5ms/step - loss: 9.5321e-05
# Epoch 251/500
# 101/101 - 0s - 5ms/step - loss: 9.1810e-05
# Epoch 252/500
# 101/101 - 1s - 5ms/step - loss: 9.1902e-05
# Epoch 253/500
# 101/101 - 0s - 5ms/step - loss: 9.3337e-05
# Epoch 254/500
# 101/101 - 0s - 5ms/step - loss: 9.2682e-05
# Epoch 255/500
# 101/101 - 0s - 4ms/step - loss: 9.3660e-05
# Epoch 256/500
# 101/101 - 1s - 7ms/step - loss: 9.3405e-05
# Epoch 257/500
# 101/101 - 0s - 5ms/step - loss: 9.7667e-05
# Epoch 258/500
# 101/101 - 0s - 4ms/step - loss: 9.2380e-05
# Epoch 259/500
# 101/101 - 0s - 4ms/step - loss: 9.3801e-05
# Epoch 260/500
# 101/101 - 0s - 4ms/step - loss: 9.2299e-05
# Epoch 261/500
# 101/101 - 0s - 4ms/step - loss: 9.5611e-05
# Epoch 262/500
# 101/101 - 0s - 4ms/step - loss: 9.3227e-05
# Epoch 263/500
# 101/101 - 0s - 4ms/step - loss: 9.2087e-05
# Epoch 264/500
# 101/101 - 0s - 5ms/step - loss: 9.5003e-05
# Epoch 265/500
# 101/101 - 0s - 4ms/step - loss: 9.3739e-05
# Epoch 266/500
# 101/101 - 0s - 5ms/step - loss: 9.2557e-05
# Epoch 267/500
# 101/101 - 0s - 4ms/step - loss: 9.2484e-05
# Epoch 268/500
# 101/101 - 0s - 4ms/step - loss: 9.3109e-05
# Epoch 269/500
# 101/101 - 0s - 4ms/step - loss: 9.1322e-05
# Epoch 270/500
# 101/101 - 0s - 5ms/step - loss: 9.0693e-05
# Epoch 271/500
# 101/101 - 0s - 5ms/step - loss: 9.7334e-05
# Epoch 272/500
# 101/101 - 0s - 5ms/step - loss: 9.1991e-05
# Epoch 273/500
# 101/101 - 0s - 5ms/step - loss: 9.6676e-05
# Epoch 274/500
# 101/101 - 0s - 5ms/step - loss: 9.1219e-05
# Epoch 275/500
# 101/101 - 0s - 5ms/step - loss: 9.3127e-05
# Epoch 276/500
# 101/101 - 0s - 4ms/step - loss: 9.2927e-05
# Epoch 277/500
# 101/101 - 0s - 4ms/step - loss: 9.1003e-05
# Epoch 278/500
# 101/101 - 0s - 5ms/step - loss: 9.1789e-05
# Epoch 279/500
# 101/101 - 0s - 5ms/step - loss: 9.1893e-05
# Epoch 280/500
# 101/101 - 0s - 5ms/step - loss: 9.2645e-05
# Epoch 281/500
# 101/101 - 0s - 5ms/step - loss: 9.2714e-05
# Epoch 282/500
# 101/101 - 0s - 4ms/step - loss: 9.1853e-05
# Epoch 283/500
# 101/101 - 0s - 5ms/step - loss: 9.5683e-05
# Epoch 284/500
# 101/101 - 0s - 4ms/step - loss: 9.4165e-05
# Epoch 285/500
# 101/101 - 0s - 5ms/step - loss: 9.3608e-05
# Epoch 286/500
# 101/101 - 0s - 4ms/step - loss: 9.1637e-05
# Epoch 287/500
# 101/101 - 0s - 5ms/step - loss: 9.1659e-05
# Epoch 288/500
# 101/101 - 1s - 5ms/step - loss: 9.3141e-05
# Epoch 289/500
# 101/101 - 0s - 4ms/step - loss: 9.5788e-05
# Epoch 290/500
# 101/101 - 0s - 5ms/step - loss: 9.4457e-05
# Epoch 291/500
# 101/101 - 0s - 5ms/step - loss: 9.1952e-05
# Epoch 292/500
# 101/101 - 0s - 4ms/step - loss: 9.1555e-05
# Epoch 293/500
# 101/101 - 1s - 5ms/step - loss: 9.3732e-05
# Epoch 294/500
# 101/101 - 0s - 5ms/step - loss: 9.2669e-05
# Epoch 295/500
# 101/101 - 0s - 5ms/step - loss: 9.0818e-05
# Epoch 296/500
# 101/101 - 0s - 5ms/step - loss: 9.1011e-05
# Epoch 297/500
# 101/101 - 0s - 5ms/step - loss: 9.8218e-05
# Epoch 298/500
# 101/101 - 0s - 4ms/step - loss: 9.3602e-05
# Epoch 299/500
# 101/101 - 0s - 4ms/step - loss: 9.1724e-05
# Epoch 300/500
# 101/101 - 0s - 4ms/step - loss: 9.3031e-05
# Epoch 301/500
# 101/101 - 0s - 4ms/step - loss: 9.3417e-05
# Epoch 302/500
# 101/101 - 0s - 5ms/step - loss: 9.3980e-05
# Epoch 303/500
# 101/101 - 0s - 4ms/step - loss: 9.1599e-05
# Epoch 304/500
# 101/101 - 0s - 5ms/step - loss: 9.6922e-05
# Epoch 305/500
# 101/101 - 0s - 5ms/step - loss: 9.2892e-05
# Epoch 306/500
# 101/101 - 0s - 5ms/step - loss: 9.0888e-05
# Epoch 307/500
# 101/101 - 0s - 5ms/step - loss: 9.5606e-05
# Epoch 308/500
# 101/101 - 1s - 5ms/step - loss: 9.5965e-05
# Epoch 309/500
# 101/101 - 0s - 4ms/step - loss: 9.2868e-05
# Epoch 310/500
# 101/101 - 0s - 4ms/step - loss: 9.2995e-05
# Epoch 311/500
# 101/101 - 0s - 5ms/step - loss: 9.0668e-05
# Epoch 312/500
# 101/101 - 0s - 4ms/step - loss: 9.3896e-05
# Epoch 313/500
# 101/101 - 0s - 5ms/step - loss: 9.2779e-05
# Epoch 314/500
# 101/101 - 0s - 4ms/step - loss: 9.2050e-05
# Epoch 315/500
# 101/101 - 0s - 5ms/step - loss: 9.0369e-05
# Epoch 316/500
# 101/101 - 0s - 5ms/step - loss: 9.0707e-05
# Epoch 317/500
# 101/101 - 1s - 5ms/step - loss: 9.4108e-05
# Epoch 318/500
# 101/101 - 0s - 5ms/step - loss: 9.3447e-05
# Epoch 319/500
# 101/101 - 0s - 5ms/step - loss: 1.0346e-04
# Epoch 320/500
# 101/101 - 0s - 5ms/step - loss: 9.4094e-05
# Epoch 321/500
# 101/101 - 1s - 5ms/step - loss: 9.1468e-05
# Epoch 322/500
# 101/101 - 0s - 4ms/step - loss: 9.4183e-05
# Epoch 323/500
# 101/101 - 0s - 5ms/step - loss: 9.4076e-05
# Epoch 324/500
# 101/101 - 0s - 4ms/step - loss: 9.5141e-05
# Epoch 325/500
# 101/101 - 0s - 5ms/step - loss: 9.2343e-05
# Epoch 326/500
# 101/101 - 0s - 4ms/step - loss: 9.2285e-05
# Epoch 327/500
# 101/101 - 0s - 4ms/step - loss: 9.2294e-05
# Epoch 328/500
# 101/101 - 0s - 4ms/step - loss: 9.3644e-05
# Epoch 329/500
# 101/101 - 0s - 4ms/step - loss: 9.5750e-05
# Epoch 330/500
# 101/101 - 0s - 5ms/step - loss: 9.2038e-05
# Epoch 331/500
# 101/101 - 0s - 5ms/step - loss: 9.4765e-05
# Epoch 332/500
# 101/101 - 0s - 5ms/step - loss: 9.6480e-05
# Epoch 333/500
# 101/101 - 0s - 5ms/step - loss: 9.3084e-05
# Epoch 334/500
# 101/101 - 0s - 5ms/step - loss: 9.3393e-05
# Epoch 335/500
# 101/101 - 0s - 4ms/step - loss: 9.2083e-05
# Epoch 336/500
# 101/101 - 0s - 5ms/step - loss: 9.3222e-05
# Epoch 337/500
# 101/101 - 0s - 4ms/step - loss: 8.9895e-05
# Epoch 338/500
# 101/101 - 0s - 5ms/step - loss: 9.3045e-05
# Epoch 339/500
# 101/101 - 0s - 5ms/step - loss: 9.2814e-05
# Epoch 340/500
# 101/101 - 0s - 5ms/step - loss: 9.5416e-05
# Epoch 341/500
# 101/101 - 0s - 5ms/step - loss: 9.2091e-05
# Epoch 342/500
# 101/101 - 0s - 5ms/step - loss: 9.4631e-05
# Epoch 343/500
# 101/101 - 0s - 5ms/step - loss: 9.2007e-05
# Epoch 344/500
# 101/101 - 0s - 5ms/step - loss: 9.0632e-05
# Epoch 345/500
# 101/101 - 0s - 4ms/step - loss: 9.4359e-05
# Epoch 346/500
# 101/101 - 0s - 5ms/step - loss: 9.2387e-05
# Epoch 347/500
# 101/101 - 0s - 5ms/step - loss: 9.5186e-05
# Epoch 348/500
# 101/101 - 0s - 4ms/step - loss: 9.5841e-05
# Epoch 349/500
# 101/101 - 0s - 5ms/step - loss: 9.1276e-05
# Epoch 350/500
# 101/101 - 1s - 6ms/step - loss: 9.3718e-05
# Epoch 351/500
# 101/101 - 0s - 5ms/step - loss: 9.2002e-05
# Epoch 352/500
# 101/101 - 0s - 5ms/step - loss: 9.5039e-05
# Epoch 353/500
# 101/101 - 1s - 5ms/step - loss: 9.1291e-05
# Epoch 354/500
# 101/101 - 0s - 5ms/step - loss: 9.2557e-05
# Epoch 355/500
# 101/101 - 0s - 5ms/step - loss: 9.1033e-05
# Epoch 356/500
# 101/101 - 1s - 6ms/step - loss: 9.3064e-05
# Epoch 357/500
# 101/101 - 1s - 6ms/step - loss: 9.0804e-05
# Epoch 358/500
# 101/101 - 1s - 6ms/step - loss: 9.4225e-05
# Epoch 359/500
# 101/101 - 1s - 6ms/step - loss: 9.5200e-05
# Epoch 360/500
# 101/101 - 1s - 7ms/step - loss: 9.7963e-05
# Epoch 361/500
# 101/101 - 1s - 6ms/step - loss: 9.1625e-05
# Epoch 362/500
# 101/101 - 1s - 6ms/step - loss: 9.3492e-05
# Epoch 363/500
# 101/101 - 1s - 5ms/step - loss: 9.3501e-05
# Epoch 364/500
# 101/101 - 1s - 6ms/step - loss: 9.6143e-05
# Epoch 365/500
# 101/101 - 1s - 6ms/step - loss: 9.1110e-05
# Epoch 366/500
# 101/101 - 1s - 6ms/step - loss: 9.4526e-05
# Epoch 367/500
# 101/101 - 1s - 6ms/step - loss: 1.0103e-04
# Epoch 368/500
# 101/101 - 1s - 6ms/step - loss: 9.3078e-05
# Epoch 369/500
# 101/101 - 1s - 5ms/step - loss: 9.1947e-05
# Epoch 370/500
# 101/101 - 1s - 6ms/step - loss: 9.2868e-05
# Epoch 371/500
# 101/101 - 1s - 7ms/step - loss: 9.5144e-05
# Epoch 372/500
# 101/101 - 1s - 6ms/step - loss: 9.5721e-05
# Epoch 373/500
# 101/101 - 1s - 6ms/step - loss: 9.3553e-05
# Epoch 374/500
# 101/101 - 1s - 6ms/step - loss: 9.2716e-05
# Epoch 375/500
# 101/101 - 1s - 6ms/step - loss: 9.2749e-05
# Epoch 376/500
# 101/101 - 1s - 6ms/step - loss: 9.2359e-05
# Epoch 377/500
# 101/101 - 1s - 6ms/step - loss: 9.2090e-05
# Epoch 378/500
# 101/101 - 1s - 6ms/step - loss: 9.4545e-05
# Epoch 379/500
# 101/101 - 1s - 5ms/step - loss: 9.3971e-05
# Epoch 380/500
# 101/101 - 0s - 5ms/step - loss: 9.1174e-05
# Epoch 381/500
# 101/101 - 1s - 5ms/step - loss: 9.2834e-05
# Epoch 382/500
# 101/101 - 0s - 5ms/step - loss: 9.2297e-05
# Epoch 383/500
# 101/101 - 0s - 5ms/step - loss: 9.4483e-05
# Epoch 384/500
# 101/101 - 1s - 5ms/step - loss: 9.4178e-05
# Epoch 385/500
# 101/101 - 1s - 5ms/step - loss: 9.1098e-05
# Epoch 386/500
# 101/101 - 1s - 9ms/step - loss: 9.4375e-05
# Epoch 387/500
# 101/101 - 1s - 5ms/step - loss: 9.3682e-05
# Epoch 388/500
# 101/101 - 1s - 6ms/step - loss: 9.3287e-05
# Epoch 389/500
# 101/101 - 1s - 6ms/step - loss: 9.2081e-05
# Epoch 390/500
# 101/101 - 1s - 6ms/step - loss: 9.2354e-05
# Epoch 391/500
# 101/101 - 1s - 7ms/step - loss: 9.1900e-05
# Epoch 392/500
# 101/101 - 1s - 6ms/step - loss: 9.2984e-05
# Epoch 393/500
# 101/101 - 1s - 6ms/step - loss: 9.1048e-05
# Epoch 394/500
# 101/101 - 1s - 6ms/step - loss: 9.1882e-05
# Epoch 395/500
# 101/101 - 1s - 6ms/step - loss: 9.7265e-05
# Epoch 396/500
# 101/101 - 1s - 6ms/step - loss: 9.1554e-05
# Epoch 397/500
# 101/101 - 1s - 6ms/step - loss: 9.3491e-05
# Epoch 398/500
# 101/101 - 1s - 5ms/step - loss: 9.2049e-05
# Epoch 399/500
# 101/101 - 0s - 5ms/step - loss: 9.4684e-05
# Epoch 400/500
# 101/101 - 0s - 5ms/step - loss: 9.1993e-05
# Epoch 401/500
# 101/101 - 0s - 5ms/step - loss: 9.3511e-05
# Epoch 402/500
# 101/101 - 0s - 4ms/step - loss: 9.5426e-05
# Epoch 403/500
# 101/101 - 0s - 5ms/step - loss: 9.6211e-05
# Epoch 404/500
# 101/101 - 0s - 5ms/step - loss: 9.3703e-05
# Epoch 405/500
# 101/101 - 0s - 5ms/step - loss: 9.2531e-05
# Epoch 406/500
# 101/101 - 0s - 5ms/step - loss: 9.2870e-05
# Epoch 407/500
# 101/101 - 0s - 5ms/step - loss: 9.2488e-05
# Epoch 408/500
# 101/101 - 0s - 5ms/step - loss: 9.3366e-05
# Epoch 409/500
# 101/101 - 0s - 5ms/step - loss: 9.4774e-05
# Epoch 410/500
# 101/101 - 0s - 5ms/step - loss: 9.7288e-05
# Epoch 411/500
# 101/101 - 1s - 5ms/step - loss: 9.5596e-05
# Epoch 412/500
# 101/101 - 0s - 5ms/step - loss: 9.1908e-05
# Epoch 413/500
# 101/101 - 0s - 5ms/step - loss: 9.2794e-05
# Epoch 414/500
# 101/101 - 0s - 5ms/step - loss: 9.1816e-05
# Epoch 415/500
# 101/101 - 0s - 5ms/step - loss: 9.3878e-05
# Epoch 416/500
# 101/101 - 0s - 4ms/step - loss: 9.2914e-05
# Epoch 417/500
# 101/101 - 0s - 5ms/step - loss: 9.1224e-05
# Epoch 418/500
# 101/101 - 0s - 5ms/step - loss: 9.3343e-05
# Epoch 419/500
# 101/101 - 1s - 5ms/step - loss: 9.1255e-05
# Epoch 420/500
# 101/101 - 0s - 5ms/step - loss: 9.3743e-05
# Epoch 421/500
# 101/101 - 0s - 5ms/step - loss: 9.3033e-05
# Epoch 422/500
# 101/101 - 0s - 5ms/step - loss: 9.2488e-05
# Epoch 423/500
# 101/101 - 0s - 5ms/step - loss: 9.5989e-05
# Epoch 424/500
# 101/101 - 0s - 5ms/step - loss: 9.5512e-05
# Epoch 425/500
# 101/101 - 0s - 5ms/step - loss: 9.1588e-05
# Epoch 426/500
# 101/101 - 0s - 5ms/step - loss: 9.1331e-05
# Epoch 427/500
# 101/101 - 0s - 5ms/step - loss: 9.1637e-05
# Epoch 428/500
# 101/101 - 1s - 5ms/step - loss: 9.4870e-05
# Epoch 429/500
# 101/101 - 0s - 5ms/step - loss: 9.5075e-05
# Epoch 430/500
# 101/101 - 0s - 5ms/step - loss: 9.8155e-05
# Epoch 431/500
# 101/101 - 0s - 5ms/step - loss: 9.2602e-05
# Epoch 432/500
# 101/101 - 0s - 5ms/step - loss: 9.2437e-05
# Epoch 433/500
# 101/101 - 1s - 5ms/step - loss: 9.1723e-05
# Epoch 434/500
# 101/101 - 0s - 5ms/step - loss: 9.1281e-05
# Epoch 435/500
# 101/101 - 0s - 5ms/step - loss: 9.2384e-05
# Epoch 436/500
# 101/101 - 0s - 4ms/step - loss: 9.1037e-05
# Epoch 437/500
# 101/101 - 0s - 5ms/step - loss: 9.0244e-05
# Epoch 438/500
# 101/101 - 0s - 5ms/step - loss: 9.1348e-05
# Epoch 439/500
# 101/101 - 1s - 5ms/step - loss: 9.3354e-05
# Epoch 440/500
# 101/101 - 0s - 5ms/step - loss: 9.4421e-05
# Epoch 441/500
# 101/101 - 0s - 5ms/step - loss: 9.2548e-05
# Epoch 442/500
# 101/101 - 0s - 5ms/step - loss: 9.1501e-05
# Epoch 443/500
# 101/101 - 0s - 5ms/step - loss: 9.3966e-05
# Epoch 444/500
# 101/101 - 0s - 4ms/step - loss: 9.4551e-05
# Epoch 445/500
# 101/101 - 0s - 5ms/step - loss: 9.1709e-05
# Epoch 446/500
# 101/101 - 1s - 5ms/step - loss: 9.5984e-05
# Epoch 447/500
# 101/101 - 0s - 4ms/step - loss: 9.1479e-05
# Epoch 448/500
# 101/101 - 0s - 5ms/step - loss: 9.3438e-05
# Epoch 449/500
# 101/101 - 0s - 5ms/step - loss: 9.1917e-05
# Epoch 450/500
# 101/101 - 0s - 5ms/step - loss: 9.5188e-05
# Epoch 451/500
# 101/101 - 0s - 4ms/step - loss: 9.2428e-05
# Epoch 452/500
# 101/101 - 0s - 5ms/step - loss: 9.2099e-05
# Epoch 453/500
# 101/101 - 0s - 4ms/step - loss: 9.4827e-05
# Epoch 454/500
# 101/101 - 0s - 5ms/step - loss: 9.2374e-05
# Epoch 455/500
# 101/101 - 0s - 5ms/step - loss: 9.2004e-05
# Epoch 456/500
# 101/101 - 0s - 5ms/step - loss: 9.4641e-05
# Epoch 457/500
# 101/101 - 0s - 5ms/step - loss: 9.1101e-05
# Epoch 458/500
# 101/101 - 0s - 5ms/step - loss: 9.0573e-05
# Epoch 459/500
# 101/101 - 0s - 4ms/step - loss: 9.1552e-05
# Epoch 460/500
# 101/101 - 0s - 5ms/step - loss: 9.6053e-05
# Epoch 461/500
# 101/101 - 0s - 4ms/step - loss: 9.2568e-05
# Epoch 462/500
# 101/101 - 0s - 5ms/step - loss: 9.1423e-05
# Epoch 463/500
# 101/101 - 0s - 5ms/step - loss: 9.3554e-05
# Epoch 464/500
# 101/101 - 0s - 5ms/step - loss: 9.3107e-05
# Epoch 465/500
# 101/101 - 1s - 5ms/step - loss: 9.2284e-05
# Epoch 466/500
# 101/101 - 0s - 5ms/step - loss: 9.4433e-05
# Epoch 467/500
# 101/101 - 0s - 4ms/step - loss: 9.3124e-05
# Epoch 468/500
# 101/101 - 0s - 5ms/step - loss: 9.4777e-05
# Epoch 469/500
# 101/101 - 0s - 5ms/step - loss: 9.1253e-05
# Epoch 470/500
# 101/101 - 0s - 5ms/step - loss: 9.2323e-05
# Epoch 471/500
# 101/101 - 0s - 5ms/step - loss: 9.6922e-05
# Epoch 472/500
# 101/101 - 0s - 5ms/step - loss: 9.0373e-05
# Epoch 473/500
# 101/101 - 0s - 5ms/step - loss: 9.4507e-05
# Epoch 474/500
# 101/101 - 0s - 5ms/step - loss: 9.3434e-05
# Epoch 475/500
# 101/101 - 0s - 5ms/step - loss: 9.1536e-05
# Epoch 476/500
# 101/101 - 0s - 5ms/step - loss: 9.4032e-05
# Epoch 477/500
# 101/101 - 0s - 5ms/step - loss: 9.4449e-05
# Epoch 478/500
# 101/101 - 0s - 5ms/step - loss: 9.4769e-05
# Epoch 479/500
# 101/101 - 0s - 5ms/step - loss: 9.2366e-05
# Epoch 480/500
# 101/101 - 0s - 5ms/step - loss: 9.4600e-05
# Epoch 481/500
# 101/101 - 0s - 5ms/step - loss: 9.0457e-05
# Epoch 482/500
# 101/101 - 0s - 4ms/step - loss: 9.1536e-05
# Epoch 483/500
# 101/101 - 0s - 4ms/step - loss: 9.3867e-05
# Epoch 484/500
# 101/101 - 0s - 4ms/step - loss: 9.3267e-05
# Epoch 485/500
# 101/101 - 0s - 4ms/step - loss: 9.3289e-05
# Epoch 486/500
# 101/101 - 0s - 5ms/step - loss: 9.2490e-05
# Epoch 487/500
# 101/101 - 0s - 5ms/step - loss: 9.7054e-05
# Epoch 488/500
# 101/101 - 0s - 4ms/step - loss: 9.1906e-05
# Epoch 489/500
# 101/101 - 0s - 5ms/step - loss: 9.1145e-05
# Epoch 490/500
# 101/101 - 0s - 5ms/step - loss: 9.3445e-05
# Epoch 491/500
# 101/101 - 0s - 5ms/step - loss: 9.0674e-05
# Epoch 492/500
# 101/101 - 0s - 5ms/step - loss: 9.2859e-05
# Epoch 493/500
# 101/101 - 0s - 4ms/step - loss: 9.3829e-05
# Epoch 494/500
# 101/101 - 0s - 4ms/step - loss: 9.1454e-05
# Epoch 495/500
# 101/101 - 0s - 4ms/step - loss: 9.3689e-05
# Epoch 496/500
# 101/101 - 0s - 5ms/step - loss: 9.0223e-05
# Epoch 497/500
# 101/101 - 0s - 4ms/step - loss: 9.2753e-05
# Epoch 498/500
# 101/101 - 0s - 4ms/step - loss: 9.3108e-05
# Epoch 499/500
# 101/101 - 0s - 5ms/step - loss: 9.1888e-05
# Epoch 500/500
# 101/101 - 0s - 5ms/step - loss: 9.1535e-05

# %% [markdown]
# <h2><h2>

# %% [markdown]
# ### The Model is now ready to make predictions.

# %% [markdown]
# ## Making Predictions.

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ### We Need to Plot the Predictions.

# %% [markdown]
# ## Shifting Train Predictions.

# %%
trainPredictPlot = np.empty_like(df2)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# %% [markdown]
# ## Shifting Test Predictions.

# %%
testPredictPlot = np.empty_like(df2)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2):len(df2), :] = testPredict

# %% [markdown]
# ## Plotting the Data

# %%
plt.figure(figsize=(16,8))
plt.plot(scaler.inverse_transform(df2), label = 'Actual Data')
plt.title('BSE Stock Price Prediction from last 5 years Data')
plt.xlabel('Time')
plt.ylabel('Actual Stock Price')
plt.plot(trainPredictPlot,color='#DE3163', label = 'Train Predicted Data')
plt.plot(testPredictPlot, color='#29c714', label = 'Test Predicted Data')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## Root Mean Square Error

# %%
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print("Training  = ",trainScore," RMSE")
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print("Testing = ",testScore," RMSE")
# Out:
# Training  =  0.493037515806604  RMSE
# Testing =  1.1060824770457887  RMSE

# %% [markdown]
# <hr>

# %% [markdown]
# # Textual Analysis

# %% [markdown]
# <h2><h2>

# %% [markdown]
# ## Headline text (News Headline) Per City

# %%
city_headline = city_data.groupby(['City_Name']).agg({'News':'count'})
city_headline.rename(columns={'News':'Number_of_headline_text'},inplace=True)
city_headline = city_headline.sort_values(by='Number_of_headline_text',ascending=False)
top_15_headline_city = city_headline.head(15)
top_15_headline_city
# Out:
#             Number_of_headline_text
# City_Name
# nagpur                           38
# bengaluru                        33
# madurai                          31
# goa                              31
# trichy                           31
# hyderabad                        29
# patna                            27
# chennai                          27
# ahmedabad                        25
# chandigarh                       19
# pune                             17
# coimbatore                       16
# nashik                           16
# vadodara                         16
# vijayawada                       16

# %% [markdown]
# ## Top 15 Cities which have high number of headline text

# %%
plt.figure(figsize=(16,8))
plt.bar(top_15_headline_city.index,height=top_15_headline_city['Number_of_headline_text'])
plt.xticks(rotation = 45)
plt.xlabel('City Name',fontsize=18)
plt.ylabel('Recorded Articles',fontsize=18)
plt.title('Top 15 Highest Headline Text\n',fontsize=24, fontweight='bold')
plt.show()

# %% [markdown]
# <h2></h2>

# %% [markdown]
# ## Sentiment Analysis of Headline Text

# %%
def getAnalysis_polarity(headline):
    result = TextBlob(headline)
    if result.sentiment.polarity < 0:
        return 'negative'
    elif result.sentiment.polarity == 0:
        return 'neutral'
    else:
        return 'positive'

# %%
df_news['Result'] = np.array([getAnalysis_polarity(headline) for headline in df_news['News']])

# %%
final_result = df_news.groupby(['Result']).agg({'News':'count'})
final_result
# Out:
#           News
# Result
# negative   176
# neutral    848
# positive   437

# %%
negative = (final_result.loc['negative'] / len(df_news))*100
neutral = (final_result.loc['neutral'] / len(df_news))*100
positive = (final_result.loc['positive'] / len(df_news))*100

# %% [markdown]
# ## Printing the Percentages

# %%
print('Positive Headlines: ' , positive )
print('\n\nNegative Headlines: ' ,negative )
print('\n\nUnbiased Headlines: ' , str(neutral))
# Out:
# Positive Headlines:  News    29.91102
# Name: positive, dtype: float64
#
#
# Negative Headlines:  News    12.046543
# Name: negative, dtype: float64
#
#
# Unbiased Headlines:  News    58.042437
# Name: neutral, dtype: float64

# %% [markdown]
# ## Plotting the Results

# %%
plt.figure(figsize=(16,8))
final_result['News'].plot.pie(autopct='%1.1f%%')
plt.title("Overall Sentiment Distribution Pie Chart",fontweight="bold")
plt.show()

# %% [markdown]
# <hr>

# %% [markdown]
# # Hybrid model for Stock Price/Perfomance Prediction

# %% [markdown]
# <h2></h2>

# %% [markdown]
# ## Loading Data

# %%
df_prices = pd.read_csv('Datasets/stockprices.csv')
cols = ['Date', 'Category', 'News']
df_news = pd.read_csv("Datasets/news.csv", names=cols)

# %%
df_news['Date'] = pd.to_datetime(df_news['Date'], format='%Y%m%d')
df_prices['Date'] = pd.to_datetime(df_prices.Date, format='%Y-%m-%d')

# %% [markdown]
# ## Making Hybrid Dataset

# %%
hybrid_data = pd.merge(df_news, df_prices, how ='inner', on='Date')
hybrid_data
# Out:
#              Date                            Category  \
# 0      2017-03-01  life-style.relationships.man-woman
# 1      2017-03-01                         city.indore
# 2      2017-03-01       entertainment.hindi.bollywood
# 3      2017-03-01     entertainment.tamil.movies.news
# 4      2017-03-01     entertainment.tamil.movies.news
# ...           ...                                 ...
# 575066 2020-12-31                        city.jodhpur
# 575067 2020-12-31                        city.udaipur
# 575068 2020-12-31                          city.ajmer
# 575069 2020-12-31                             removed
# 575070 2020-12-31   entertainment.bengali.movies.news
#
#                                                      News   Open       High  \
# 0                         Beginner's guide to rocking sex  26.01  26.379999
# 1       With only 58 PUC centres; Indore fails to curb...  26.01  26.379999
# 2       You can't miss Sonakshi Sinha's underwater pic...  26.01  26.379999
# 3                 Cheran and Vijay Sethupathi to team up?  26.01  26.379999
# 4                Sonia Aggarwal to play a cop in her next  26.01  26.379999
# ...                                                   ...    ...        ...
# 575066  Covid-19: Despite dip in cases; Rajasthan amon...  31.00  31.540001
# 575067  Covid-19: Despite dip in cases; Rajasthan amon...  31.00  31.540001
# 575068  Covid-19: Despite dip in cases; Rajasthan amon...  31.00  31.540001
# 575069  Govt extends deadline for use of FASTag till F...  31.00  31.540001
# 575070  Celebs plan to party safely and responsibly on...  31.00  31.540001
#
#               Low  Close  Adj Close  Volume
# 0       25.860001  25.90  24.324486   55900
# 1       25.860001  25.90  24.324486   55900
# 2       25.860001  25.90  24.324486   55900
# 3       25.860001  25.90  24.324486   55900
# 4       25.860001  25.90  24.324486   55900
# ...           ...    ...        ...     ...
# 575066  30.910000  31.32  30.921082   53200
# 575067  30.910000  31.32  30.921082   53200
# 575068  30.910000  31.32  30.921082   53200
# 575069  30.910000  31.32  30.921082   53200
# 575070  30.910000  31.32  30.921082   53200
#
# [575071 rows x 9 columns]

# %% [markdown]
# ## Performing Sentiment Analysis

# %%
def analysis_polarity(headline):
    result = TextBlob(headline)
    if result.sentiment.polarity < 0:
        return 'negative'
    elif result.sentiment.polarity == 0:
        return 'neutral'
    else:
        return 'positive'

# %%
hybrid_data['sentiment'] = np.array([analysis_polarity(headline) for headline in hybrid_data['News']])

# %%
senti_data = pd.get_dummies(hybrid_data['sentiment'],drop_first=True)
hybrid_data = pd.concat([hybrid_data,senti_data],axis=1)
hybrid_data.head()
# Out:
#         Date                            Category  \
# 0 2017-03-01  life-style.relationships.man-woman
# 1 2017-03-01                         city.indore
# 2 2017-03-01       entertainment.hindi.bollywood
# 3 2017-03-01     entertainment.tamil.movies.news
# 4 2017-03-01     entertainment.tamil.movies.news
#
#                                                 News   Open       High  \
# 0                    Beginner's guide to rocking sex  26.01  26.379999
# 1  With only 58 PUC centres; Indore fails to curb...  26.01  26.379999
# 2  You can't miss Sonakshi Sinha's underwater pic...  26.01  26.379999
# 3            Cheran and Vijay Sethupathi to team up?  26.01  26.379999
# 4           Sonia Aggarwal to play a cop in her next  26.01  26.379999
#
#          Low  Close  Adj Close  Volume sentiment  neutral  positive
# 0  25.860001   25.9  24.324486   55900   neutral     True     False
# 1  25.860001   25.9  24.324486   55900  negative    False     False
# 2  25.860001   25.9  24.324486   55900   neutral     True     False
# 3  25.860001   25.9  24.324486   55900   neutral     True     False
# 4  25.860001   25.9  24.324486   55900   neutral     True     False

# %% [markdown]
# ## Subjectivity and Polarity Scores

# %%
def getSubjectivity(text):
  return TextBlob(text).sentiment.subjectivity
def getPolarity(text):
  return  TextBlob(text).sentiment.polarity

# %%
hybrid_data['Subjectivity'] =hybrid_data['News'].apply(getSubjectivity)
hybrid_data['Polarity'] = hybrid_data['News'].apply(getPolarity)
hybrid_data.head()
# Out:
#         Date                            Category  \
# 0 2017-03-01  life-style.relationships.man-woman
# 1 2017-03-01                         city.indore
# 2 2017-03-01       entertainment.hindi.bollywood
# 3 2017-03-01     entertainment.tamil.movies.news
# 4 2017-03-01     entertainment.tamil.movies.news
#
#                                                 News   Open       High  \
# 0                    Beginner's guide to rocking sex  26.01  26.379999
# 1  With only 58 PUC centres; Indore fails to curb...  26.01  26.379999
# 2  You can't miss Sonakshi Sinha's underwater pic...  26.01  26.379999
# 3            Cheran and Vijay Sethupathi to team up?  26.01  26.379999
# 4           Sonia Aggarwal to play a cop in her next  26.01  26.379999
#
#          Low  Close  Adj Close  Volume sentiment  neutral  positive  \
# 0  25.860001   25.9  24.324486   55900   neutral     True     False
# 1  25.860001   25.9  24.324486   55900  negative    False     False
# 2  25.860001   25.9  24.324486   55900   neutral     True     False
# 3  25.860001   25.9  24.324486   55900   neutral     True     False
# 4  25.860001   25.9  24.324486   55900   neutral     True     False
#
#    Subjectivity  Polarity
# 0          0.00      0.00
# 1          0.65     -0.25
# 2          0.00      0.00
# 3          0.00      0.00
# 4          0.00      0.00

# %% [markdown]
# ## Plotting the Scores

# %%
plt.figure(figsize = (20,8))
plt.title('News Polarity')
hybrid_data['Polarity'].hist(color = '#2BF6F9')
# Out:
# <Axes: title={'center': 'News Polarity'}>

# %%
plt.figure(figsize = (20,8))
plt.title('News Subjectivity')
hybrid_data['Subjectivity'].hist(color = '#F92BD1')
# Out:
# <Axes: title={'center': 'News Subjectivity'}>

# %% [markdown]
# ## Performing Sentiment Analysis

# %%
senti_int_an = SentimentIntensityAnalyzer()
hybrid_data['Compound'] = [senti_int_an.polarity_scores(v)['compound'] for v in hybrid_data['News']]
hybrid_data['Negative'] = [senti_int_an.polarity_scores(v)['neg'] for v in hybrid_data['News']]
hybrid_data['Neutral'] = [senti_int_an.polarity_scores(v)['neu'] for v in hybrid_data['News']]
hybrid_data['Positive'] = [senti_int_an.polarity_scores(v)['pos'] for v in hybrid_data['News']]
hybrid_data.head()
# Out:
#         Date                            Category  \
# 0 2017-03-01  life-style.relationships.man-woman
# 1 2017-03-01                         city.indore
# 2 2017-03-01       entertainment.hindi.bollywood
# 3 2017-03-01     entertainment.tamil.movies.news
# 4 2017-03-01     entertainment.tamil.movies.news
#
#                                                 News   Open       High  \
# 0                    Beginner's guide to rocking sex  26.01  26.379999
# 1  With only 58 PUC centres; Indore fails to curb...  26.01  26.379999
# 2  You can't miss Sonakshi Sinha's underwater pic...  26.01  26.379999
# 3            Cheran and Vijay Sethupathi to team up?  26.01  26.379999
# 4           Sonia Aggarwal to play a cop in her next  26.01  26.379999
#
#          Low  Close  Adj Close  Volume sentiment  neutral  positive  \
# 0  25.860001   25.9  24.324486   55900   neutral     True     False
# 1  25.860001   25.9  24.324486   55900  negative    False     False
# 2  25.860001   25.9  24.324486   55900   neutral     True     False
# 3  25.860001   25.9  24.324486   55900   neutral     True     False
# 4  25.860001   25.9  24.324486   55900   neutral     True     False
#
#    Subjectivity  Polarity  Compound  Negative  Neutral  Positive
# 0          0.00      0.00    0.0000     0.000    1.000     0.000
# 1          0.65     -0.25   -0.4215     0.237    0.763     0.000
# 2          0.00      0.00    0.1139     0.000    0.806     0.194
# 3          0.00      0.00    0.0000     0.000    1.000     0.000
# 4          0.00      0.00    0.3400     0.000    0.769     0.231

# %%
req_col = ['Open', 'High', 'Low', 'Volume', 'Compound', 'Negative', 'Neutral', 'Positive', 'positive']

# %%
new_hybrid = hybrid_data[req_col]
new_hybrid.reset_index(inplace = True)
new_hybrid.rename(columns = {'positive':'Label'}, inplace = True)
new_hybrid = new_hybrid.loc[:,~new_hybrid.columns.duplicated()]
# Out:
# C:\Users\Lovkush\AppData\Local\Temp\ipykernel_1384\4192071081.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_hybrid.rename(columns = {'positive':'Label'}, inplace = True)

# %%
new_hybrid
# Out:
#          index   Open       High        Low  Volume  Compound  Negative  \
# 0            0  26.01  26.379999  25.860001   55900    0.0000     0.000
# 1            1  26.01  26.379999  25.860001   55900   -0.4215     0.237
# 2            2  26.01  26.379999  25.860001   55900    0.1139     0.000
# 3            3  26.01  26.379999  25.860001   55900    0.0000     0.000
# 4            4  26.01  26.379999  25.860001   55900    0.3400     0.000
# ...        ...    ...        ...        ...     ...       ...       ...
# 575066  575066  31.00  31.540001  30.910000   53200    0.2023     0.000
# 575067  575067  31.00  31.540001  30.910000   53200    0.2023     0.000
# 575068  575068  31.00  31.540001  30.910000   53200    0.2023     0.000
# 575069  575069  31.00  31.540001  30.910000   53200    0.1280     0.000
# 575070  575070  31.00  31.540001  30.910000   53200    0.7096     0.000
#
#         Neutral  Positive  Label
# 0         1.000     0.000  False
# 1         0.763     0.000  False
# 2         0.806     0.194  False
# 3         1.000     0.000  False
# 4         0.769     0.231  False
# ...         ...       ...    ...
# 575066    0.870     0.130   True
# 575067    0.870     0.130   True
# 575068    0.870     0.130   True
# 575069    0.857     0.143  False
# 575070    0.604     0.396   True
#
# [575071 rows x 10 columns]

# %% [markdown]
# ## Training and Testing the Models for Stock Price/Performance Analysis

# %%
X = new_hybrid.drop('Label', axis=1)    
y = new_hybrid['Label']
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 0)

# %%
np.any(np.isnan(x_train))
np.all(np.isfinite(x_train))
x_train = x_train.fillna(x_train.mean())
x_test = x_test.fillna(x_test.mean())

# %% [markdown]
# ## Logistic Regressor Model

# %%
logit = LogisticRegression()
logit.fit(x_train,y_train)
y_logit_pred = logit.predict(x_test)
accuracy_score(y_test,y_logit_pred)
# Out:
# 0.8043124809807416

# %% [markdown]
# ## Random Forest Model

# %%
rf = RandomForestClassifier(n_estimators=200)
rf.fit(x_train,y_train)
y_rf_pred = rf.predict(x_test)
accuracy_score(y_test,y_rf_pred)
# Out:
# 0.7810198669738729

# %% [markdown]
# ## Decision Tree Model

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
y_dt_pred = dt.predict(x_test)
accuracy_score(y_test,y_dt_pred)
# Out:
# 0.7516497848106769

# %% [markdown]
# ## Linear Discriminant Analyser Model

# %%
lda = LinearDiscriminantAnalysis()
lda.fit(x_train, y_train)
y_lda_pred = lda.predict(x_test)
accuracy_score(y_test,y_lda_pred)
# Out:
# 0.8076250923792548

# %% [markdown]
# ## AdaBoost Model

# %%
adb = AdaBoostClassifier()
adb.fit(x_train, y_train)
y_adb_pred = adb.predict(x_test)
accuracy_score(y_test,y_adb_pred)
# Out:
# 0.8206147024301178

# %% [markdown]
# ## Logistic Gradient Boosting Model

# %%
xgb = GradientBoostingClassifier()
xgb.fit(x_train, y_train)
y_xgb_pred = xgb.predict(x_test)
accuracy_score(y_test,y_xgb_pred)
# Out:
# 0.8224492457505542

# %% [markdown]
# <h2></h2>

# %% [markdown]
# <hr>

# %% [markdown]
# ## Plotting Accuracy Graph

# %%
print("Accuracy of Logistic Regression Model: ",accuracy_score(y_test,y_logit_pred)*100,"%")
print("Accuracy of Random forest Model      : ",accuracy_score(y_test,y_rf_pred)*100,"%")
print("Accuracy of Decision Tree Model      : ",accuracy_score(y_test,y_dt_pred)*100,"%")
print("Accuracy of Linear Discriminant Mode  : ",accuracy_score(y_test,y_lda_pred)*100,"%")
print("Accuracy of AdaBoost Model           : ",accuracy_score(y_test,y_adb_pred)*100,"%")
print("Accuracy of Gradient Boosting Model  : ",accuracy_score(y_test,y_xgb_pred)*100,"%")
# Out:
# Accuracy of Logistic Regression Model:  80.43124809807416 %
# Accuracy of Random forest Model      :  78.10198669738729 %
# Accuracy of Decision Tree Model      :  75.16497848106769 %
# Accuracy of Linear Discriminant Mode  :  80.76250923792549 %
# Accuracy of AdaBoost Model           :  82.06147024301178 %
# Accuracy of Gradient Boosting Model  :  82.24492457505542 %

# %%
model = ["Logistic Regression", "Random Forest", "Decision Tree", "Linear Discriminant", "AdaBoost", "Gradient Boosting"]
accuracy = [accuracy_score(y_test,y_logit_pred)*100, accuracy_score(y_test,y_rf_pred)*100, accuracy_score(y_test,y_dt_pred)*100, accuracy_score(y_test,y_lda_pred)*100, accuracy_score(y_test,y_adb_pred)*100, accuracy_score(y_test,y_xgb_pred)*100]

# %%
plt.figure(figsize=(20,5))
plt.bar(model,accuracy)
plt.xticks(rotation = 45)
plt.xlabel('Model Name/Type',fontsize=18)
plt.ylabel('Accuracy %',fontsize=18)
plt.title('Prediction Model Accuracy',fontsize=24, fontweight='bold')
plt.show()

# %% [markdown]
# <hr>

# %% [markdown]
# # Conclusion

# %% [markdown]
# ### Here, I have used six different Neural Network models to carry out the analysis and prediction of stock price/performance and train them with Hybrid data generated from Numerical data

# %%
print(f"The hightest accuracy is {max(accuracy)}%")
print(f"The hightest accuracy is {model[accuracy.index(max(accuracy))]}")
print(f"At the end, we can clearly see that {model[accuracy.index(max(accuracy))]} Model gives more accuracy(== {max(accuracy)}%) as compared to all other models.It performs better on Analysis and prediction of Stock price/performance than other 5 Neural Network Models.")
# Out:
# The hightest accuracy is 82.24492457505542%
# The hightest accuracy is Gradient Boosting
# At the end, we can clearly see that Gradient Boosting Model gives more accuracy(== 82.24492457505542%) as compared to all other models.It performs better on Analysis and prediction of Stock price/performance than other 5 Neural Network Models.

# %% [markdown]
# <hr>
